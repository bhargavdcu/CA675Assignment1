# %%
import pandas as pd;

# %%
stack_posts = pd.read_csv("/home/sunny/675_Submission/FQ.csv")

# %%
stack_posts.head()
# Out:
#            Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  \
# 0    927358.0         1.0          927386.0       NaN  2009-05-29 18:09:14
# 1   2003505.0         1.0         2003515.0       NaN  2010-01-05 01:12:15
# 2   5767325.0         1.0         5767357.0       NaN  2011-04-23 22:17:18
# 3  16956810.0         1.0        16957078.0       NaN  2013-06-06 08:06:45
# 4   2906582.0         1.0         2906586.0       NaN  2010-05-25 16:39:47
#
#    DeletionDate    Score   ViewCount  \
# 0           NaN  23348.0  10062790.0
# 1           NaN  18514.0   9285139.0
# 2           NaN   9931.0   8937271.0
# 3           NaN   6304.0   8229811.0
# 4           NaN   2306.0   7805008.0
#
#                                                 Body  OwnerUserId  ...  \
# 0  <p>I accidentally <strong>committed the wrong ...      89904.0  ...
# 1  <p>I want to delete a branch both locally and ...      95592.0  ...
# 2  <p>I have an array of numbers and I'm using th...     364969.0  ...
# 3  <p>I'm trying to find a way to scan my entire ...     954986.0  ...
# 4  <p>I would like to create an HTML button that ...      48523.0  ...
#
#       LastActivityDate                                              Title  \
# 0  2021-10-05 13:26:47  How do I undo the most recent local commits in...
# 1  2021-10-06 22:38:35  How do I delete a Git branch locally and remot...
# 2  2021-09-24 08:51:22    How can I remove a specific item from an array?
# 3  2021-08-30 13:56:02  How do I find all files containing specific te...
# 4  2021-09-22 19:42:43  How to create an HTML button that acts like a ...
#
#                                                 Tags AnswerCount CommentCount  \
# 0           <git><version-control><git-commit><undo>        98.0         10.0
# 1  <git><version-control><git-branch><git-push><g...        41.0         10.0
# 2                               <javascript><arrays>       112.0          5.0
# 3               <linux><text><grep><directory><find>        53.0         10.0
# 4                  <html><button><hyperlink><anchor>        37.0          9.0
#
#   FavoriteCount ClosedDate   CommunityOwnedDate  ContentLicense  \
# 0        7322.0        NaN  2013-03-16 10:08:31    CC BY-SA 4.0
# 1        5727.0        NaN                  NaN    CC BY-SA 4.0
# 2        1507.0        NaN                  NaN    CC BY-SA 4.0
# 3        3036.0        NaN                  NaN    CC BY-SA 3.0
# 4         503.0        NaN                  NaN    CC BY-SA 4.0
#
#        DisplayName
# 0  Hamza Yerlikaya
# 1   Matthew Rankin
# 2           Walker
# 3           Nathan
# 4           Andrew
#
# [5 rows x 24 columns]

# %%
#To Clean Body Column
stack_posts['Body'] = stack_posts['Body'].str.replace(r'\n','',regex=True)
stack_posts['Body'] = stack_posts['Body'].str.replace('[^A-Za-z0-9 ]+',' ',regex=True)
#To Clean Title Column
stack_posts['Title'] = stack_posts['Title'].str.replace(r'\n','',regex=True)
stack_posts['Title'] = stack_posts['Title'].str.replace('[^A-Za-z0-9 ]+',' ',regex=True)

# %%
stack_posts.head()
# Out:
#            Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  \
# 0    927358.0         1.0          927386.0       NaN  2009-05-29 18:09:14
# 1   2003505.0         1.0         2003515.0       NaN  2010-01-05 01:12:15
# 2   5767325.0         1.0         5767357.0       NaN  2011-04-23 22:17:18
# 3  16956810.0         1.0        16957078.0       NaN  2013-06-06 08:06:45
# 4   2906582.0         1.0         2906586.0       NaN  2010-05-25 16:39:47
#
#    DeletionDate    Score   ViewCount  \
# 0           NaN  23348.0  10062790.0
# 1           NaN  18514.0   9285139.0
# 2           NaN   9931.0   8937271.0
# 3           NaN   6304.0   8229811.0
# 4           NaN   2306.0   7805008.0
#
#                                                 Body  OwnerUserId  ...  \
# 0   p I accidentally  strong committed the wrong ...      89904.0  ...
# 1   p I want to delete a branch both locally and ...      95592.0  ...
# 2   p I have an array of numbers and I m using th...     364969.0  ...
# 3   p I m trying to find a way to scan my entire ...     954986.0  ...
# 4   p I would like to create an HTML button that ...      48523.0  ...
#
#       LastActivityDate                                              Title  \
# 0  2021-10-05 13:26:47  How do I undo the most recent local commits in...
# 1  2021-10-06 22:38:35  How do I delete a Git branch locally and remotely
# 2  2021-09-24 08:51:22     How can I remove a specific item from an array
# 3  2021-08-30 13:56:02  How do I find all files containing specific te...
# 4  2021-09-22 19:42:43  How to create an HTML button that acts like a ...
#
#                                                 Tags AnswerCount CommentCount  \
# 0           <git><version-control><git-commit><undo>        98.0         10.0
# 1  <git><version-control><git-branch><git-push><g...        41.0         10.0
# 2                               <javascript><arrays>       112.0          5.0
# 3               <linux><text><grep><directory><find>        53.0         10.0
# 4                  <html><button><hyperlink><anchor>        37.0          9.0
#
#   FavoriteCount ClosedDate   CommunityOwnedDate  ContentLicense  \
# 0        7322.0        NaN  2013-03-16 10:08:31    CC BY-SA 4.0
# 1        5727.0        NaN                  NaN    CC BY-SA 4.0
# 2        1507.0        NaN                  NaN    CC BY-SA 4.0
# 3        3036.0        NaN                  NaN    CC BY-SA 3.0
# 4         503.0        NaN                  NaN    CC BY-SA 4.0
#
#        DisplayName
# 0  Hamza Yerlikaya
# 1   Matthew Rankin
# 2           Walker
# 3           Nathan
# 4           Andrew
#
# [5 rows x 24 columns]

# %%
stack_posts.to_csv('FQ_Stack.csv', index=False)
